# %% [markdown]
# <a href="https://colab.research.google.com/github/blackjackethey/ENGR-350-Section-5/blob/master/PhoneNeuralNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# Read the data
train = pd.read_csv('data/train.csv')
train.sample(5)
# Out:
#       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 1576           1110     0          1.5  ...             0     0            0
# 1799           1250     1          1.5  ...             1     1            2
# 85             1412     1          2.4  ...             0     1            1
# 59             1063     0          1.4  ...             1     1            2
# 1106           1266     0          2.6  ...             1     1            0
#
# [5 rows x 21 columns]
